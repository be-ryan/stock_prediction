# %% [markdown]
# <a href="https://colab.research.google.com/github/be-ryan/stock_prediction/blob/main/Stock_Prediction_CNN_GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preprocessing and Analysis

# %%
# Import libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

# %%
# Import libraries
import math
import seaborn as sns
import datetime as dt
from datetime import datetime
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# For data preprocessing and analysis part
data = pd.read_excel('/content/drive/MyDrive/MachineLearning/BBCA_dataprice.xlsx')
data.head()
# Out:
#         Date         Open         High          Low        Close      Volume  \
# 0 2017-07-31  3435.631645  3477.191706  3431.013861  3454.102783  65311000.0
# 1 2017-08-01  3486.427273  3504.898411  3458.720566  3495.662842  88810000.0
# 2 2017-08-02  3495.662842  3504.898411  3477.191704  3495.662842  62681500.0
# 3 2017-08-03  3518.751793  3518.751793  3426.396103  3463.338379  43917500.0
# 4 2017-08-04  3463.338654  3463.338654  3426.396375  3431.014160  70007000.0
#
#    Dividends  Stock Splits
# 0        0.0             0
# 1        0.0             0
# 2        0.0             0
# 3        0.0             0
# 4        0.0             0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1256 non-null   datetime64[ns]
#  1   Open          1255 non-null   float64
#  2   High          1255 non-null   float64
#  3   Low           1255 non-null   float64
#  4   Close         1255 non-null   float64
#  5   Volume        1255 non-null   float64
#  6   Dividends     1256 non-null   float64
#  7   Stock Splits  1256 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 78.6 KB

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1255.000000  1255.000000  1255.000000  1255.000000  1.255000e+03
# mean   5615.642379  5666.128212  5558.915038  5612.780879  7.983317e+07
# std    1186.870797  1196.635812  1174.073975  1184.910905  4.870713e+07
# min    3435.631645  3463.338435  3417.160615  3431.014160  0.000000e+00
# 25%    4483.680176  4530.385016  4446.316309  4483.680176  5.269025e+07
# 50%    5674.348905  5712.178006  5636.520720  5674.349609  7.020700e+07
# 75%    6404.430224  6451.279984  6363.451912  6400.107910  9.668335e+07
# max    8250.000000  8250.000000  8075.000000  8200.000000  5.379715e+08
#
#          Dividends  Stock Splits
# count  1256.000000   1256.000000
# mean      0.382962      0.003981
# std       5.336629      0.141083
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max     120.000000      5.000000

# %%
data.isnull().sum()
# Out:
# Date            0
# Open            1
# High            1
# Low             1
# Close           1
# Volume          1
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
data.reset_index(drop=True, inplace=True)
data.fillna(data.mean(), inplace=True)
data.head()
# Out:
# <ipython-input-80-fa1560e9013b>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.fillna(data.mean(), inplace=True)
#         Date         Open         High          Low        Close      Volume  \
# 0 2017-07-31  3435.631645  3477.191706  3431.013861  3454.102783  65311000.0
# 1 2017-08-01  3486.427273  3504.898411  3458.720566  3495.662842  88810000.0
# 2 2017-08-02  3495.662842  3504.898411  3477.191704  3495.662842  62681500.0
# 3 2017-08-03  3518.751793  3518.751793  3426.396103  3463.338379  43917500.0
# 4 2017-08-04  3463.338654  3463.338654  3426.396375  3431.014160  70007000.0
#
#    Dividends  Stock Splits
# 0        0.0             0
# 1        0.0             0
# 2        0.0             0
# 3        0.0             0
# 4        0.0             0

# %%
# check if there's any missing value from the data
# data.isnull().sum()

# %%
data.plot(legend=True,subplots=True, figsize = (12, 6))
plt.show()
#data['Close'].plot(legend=True, figsize = (12, 6))
#plt.show()
#data['Volume'].plot(legend=True,figsize=(12,7))
#plt.show()

data.shape
data.size
data.describe(include='all').T
data.dtypes
data.nunique()
ma_day = [10,50,100]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    data[column_name]=pd.DataFrame.rolling(data['Close'],ma).mean()

data['Daily Return'] = data['Close'].pct_change()
# plot the daily return percentage
data['Daily Return'].plot(figsize=(12,5),legend=True,linestyle=':',marker='o')
plt.show()

sns.displot(data['Daily Return'].dropna(),bins=100,color='green')
plt.show()

date=pd.DataFrame(data['Date'])
closing_df1 = pd.DataFrame(data['Close'])
close1  = closing_df1.rename(columns={"Close": "data_close"})
close2=pd.concat([date,close1],axis=1)
close2.head()

data.reset_index(drop=True, inplace=True)
data.fillna(data.mean(), inplace=True)
data.head()

data.nunique()

data.sort_index(axis=1,ascending=True)

cols_plot = ['Open', 'High', 'Low','Close','Volume','MA for 10 days','MA for 50 days','MA for 100 days','Daily Return']
axes = data[cols_plot].plot(marker='.', alpha=0.7, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily trade')

plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

data.isnull().sum()
# Out:
# <ipython-input-82-9a77a06bb070>:10: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include='all').T
# <ipython-input-82-9a77a06bb070>:34: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.fillna(data.mean(), inplace=True)
#            Date         Open         High          Low        Close  \
# 0    2017-07-31  3435.631645  3477.191706  3431.013861  3454.102783
# 1    2017-08-01  3486.427273  3504.898411  3458.720566  3495.662842
# 2    2017-08-02  3495.662842  3504.898411  3477.191704  3495.662842
# 3    2017-08-03  3518.751793  3518.751793  3426.396103  3463.338379
# 4    2017-08-04  3463.338654  3463.338654  3426.396375  3431.014160
# ...         ...          ...          ...          ...          ...
# 1251 2022-07-25  7350.000000  7375.000000  7300.000000  7300.000000
# 1252 2022-07-26  7250.000000  7375.000000  7250.000000  7300.000000
# 1253 2022-07-27  7325.000000  7350.000000  7275.000000  7325.000000
# 1254 2022-07-28  7375.000000  7450.000000  7325.000000  7350.000000
# 1255 2022-07-29  7400.000000  7475.000000  7375.000000  7425.000000
#
#           Volume  Dividends  Stock Splits  MA for 10 days  MA for 50 days  \
# 0     65311000.0        0.0             0     5614.243732     5621.481244
# 1     88810000.0        0.0             0     5614.243732     5621.481244
# 2     62681500.0        0.0             0     5614.243732     5621.481244
# 3     43917500.0        0.0             0     5614.243732     5621.481244
# 4     70007000.0        0.0             0     5614.243732     5621.481244
# ...          ...        ...           ...             ...             ...
# 1251  31247600.0        0.0             0     7195.000000     7363.000000
# 1252  44379900.0        0.0             0     7207.500000     7363.500000
# 1253  58465500.0        0.0             0     7240.000000     7363.500000
# 1254  86909700.0        0.0             0     7272.500000     7362.500000
# 1255  60044300.0        0.0             0     7315.000000     7359.500000
#
#       MA for 100 days  Daily Return
# 0         5620.436172      0.000744
# 1         5620.436172      0.012032
# 2         5620.436172      0.000000
# 3         5620.436172     -0.009247
# 4         5620.436172     -0.009333
# ...               ...           ...
# 1251      7597.700010     -0.003413
# 1252      7592.646235      0.000000
# 1253      7587.596235      0.003425
# 1254      7583.288687      0.003413
# 1255      7578.253779      0.010204
#
# [1256 rows x 12 columns]
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Volume             0
# Dividends          0
# Stock Splits       0
# MA for 10 days     0
# MA for 50 days     0
# MA for 100 days    0
# Daily Return       0
# dtype: int64

# %%
cols_plot = ['Open', 'High', 'Low','Close']
axes = data[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily trade')

# %%
plt.plot(data['Close'], label="Close price")
plt.xlabel("Timestamp")
plt.ylabel("Closing price")
df = data
print(df)

df.describe().transpose()
# Out:
#            Date         Open         High          Low        Close  \
# 0    2017-07-31  3435.631645  3477.191706  3431.013861  3454.102783
# 1    2017-08-01  3486.427273  3504.898411  3458.720566  3495.662842
# 2    2017-08-02  3495.662842  3504.898411  3477.191704  3495.662842
# 3    2017-08-03  3518.751793  3518.751793  3426.396103  3463.338379
# 4    2017-08-04  3463.338654  3463.338654  3426.396375  3431.014160
# ...         ...          ...          ...          ...          ...
# 1251 2022-07-25  7350.000000  7375.000000  7300.000000  7300.000000
# 1252 2022-07-26  7250.000000  7375.000000  7250.000000  7300.000000
# 1253 2022-07-27  7325.000000  7350.000000  7275.000000  7325.000000
# 1254 2022-07-28  7375.000000  7450.000000  7325.000000  7350.000000
# 1255 2022-07-29  7400.000000  7475.000000  7375.000000  7425.000000
#
#           Volume  Dividends  Stock Splits  MA for 10 days  MA for 50 days  \
# 0     65311000.0        0.0             0     5614.243732     5621.481244
# 1     88810000.0        0.0             0     5614.243732     5621.481244
# 2     62681500.0        0.0             0     5614.243732     5621.481244
# 3     43917500.0        0.0             0     5614.243732     5621.481244
# 4     70007000.0        0.0             0     5614.243732     5621.481244
# ...          ...        ...           ...             ...             ...
# 1251  31247600.0        0.0             0     7195.000000     7363.000000
# 1252  44379900.0        0.0             0     7207.500000     7363.500000
# 1253  58465500.0        0.0             0     7240.000000     7363.500000
# 1254  86909700.0        0.0             0     7272.500000     7362.500000
# 1255  60044300.0        0.0             0     7315.000000     7359.500000
#
#       MA for 100 days  Daily Return
# 0         5620.436172      0.000744
# 1         5620.436172      0.012032
# 2         5620.436172      0.000000
# 3         5620.436172     -0.009247
# 4         5620.436172     -0.009333
# ...               ...           ...
# 1251      7597.700010     -0.003413
# 1252      7592.646235      0.000000
# 1253      7587.596235      0.003425
# 1254      7583.288687      0.003413
# 1255      7578.253779      0.010204
#
# [1256 rows x 12 columns]
#                   count          mean           std          min  \
# Open             1256.0  5.615642e+03  1.186398e+03  3435.631645
# High             1256.0  5.666128e+03  1.196159e+03  3463.338435
# Low              1256.0  5.558915e+03  1.173606e+03  3417.160615
# Close            1256.0  5.612781e+03  1.184439e+03  3431.014160
# Volume           1256.0  7.983317e+07  4.868772e+07     0.000000
# Dividends        1256.0  3.829618e-01  5.336629e+00     0.000000
# Stock Splits     1256.0  3.980892e-03  1.410832e-01     0.000000
# MA for 10 days   1256.0  5.614244e+03  1.167926e+03  3467.956250
# MA for 50 days   1256.0  5.621481e+03  1.100470e+03  3540.270840
# MA for 100 days  1256.0  5.620436e+03  1.009163e+03  3697.603215
# Daily Return     1256.0  7.441939e-04  1.647322e-02    -0.103908
#
#                           25%           50%           75%           max
# Open             4.483680e+03  5.674349e+03  6.404137e+03  8.250000e+03
# High             4.530385e+03  5.709814e+03  6.451280e+03  8.250000e+03
# Low              4.446316e+03  5.636520e+03  6.362302e+03  8.075000e+03
# Close            4.483680e+03  5.674350e+03  6.400108e+03  8.200000e+03
# Volume           5.269762e+07  7.032975e+07  9.665968e+07  5.379715e+08
# Dividends        0.000000e+00  0.000000e+00  0.000000e+00  1.200000e+02
# Stock Splits     0.000000e+00  0.000000e+00  0.000000e+00  5.000000e+00
# MA for 10 days   4.520110e+03  5.680497e+03  6.381703e+03  7.892500e+03
# MA for 50 days   4.609048e+03  5.698891e+03  6.264872e+03  7.844730e+03
# MA for 100 days  4.829321e+03  5.620436e+03  6.215631e+03  7.700950e+03
# Daily Return    -6.554017e-03  0.000000e+00  7.687387e-03  1.733334e-01

# %%
from sklearn.model_selection import train_test_split

X = []
Y = []
window_size=100
for i in range(1 , len(df) - window_size -1 , 1):
    first = df.iloc[i,2]
    temp = []
    temp2 = []
    for j in range(window_size):
        temp.append((df.iloc[i + j, 2] - first) / first)
    temp2.append((df.iloc[i + window_size, 2] - first) / first)
    X.append(np.array(temp).reshape(100, 1))
    Y.append(np.array(temp2).reshape(1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)

train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

train_X = train_X.reshape(train_X.shape[0],1,100,1)
test_X = test_X.reshape(test_X.shape[0],1,100,1)

print(len(train_X))
print(len(test_X))
# Out:
# 923
# 231

# %% [markdown]
# # Training

# %%
# For creating model and training
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError

model = tf.keras.Sequential()

# Creating the Neural Network model here...
# CNN layers
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu', input_shape=(None, 100, 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))

# GRU layers
model.add(GRU(units=100, return_sequences=True))
model.add(Dropout(0.5))
model.add(GRU(units=100, return_sequences=False))
model.add(Dropout(0.5))

#Final layers
model.add(Dense(1, activation='linear'))
# model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae']) # added root mean square error v
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae', RootMeanSquaredError()])

history = model.fit(train_X, train_Y, validation_data=(test_X,test_Y), epochs=40,batch_size=40, verbose=1, shuffle =True)
# Out:
# Epoch 1/40
# 24/24 [==============================] - 8s 110ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0633 - root_mean_squared_error: 0.0824 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0415 - val_root_mean_squared_error: 0.0535
# Epoch 2/40
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0449 - root_mean_squared_error: 0.0595 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0353 - val_root_mean_squared_error: 0.0457
# Epoch 3/40
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0398 - root_mean_squared_error: 0.0524 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0439
# Epoch 4/40
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0378 - root_mean_squared_error: 0.0499 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0295 - val_root_mean_squared_error: 0.0407
# Epoch 5/40
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0373 - root_mean_squared_error: 0.0497 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0330 - val_root_mean_squared_error: 0.0427
# Epoch 6/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0368 - root_mean_squared_error: 0.0482 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0334 - val_root_mean_squared_error: 0.0431
# Epoch 7/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0339 - root_mean_squared_error: 0.0455 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0306 - val_root_mean_squared_error: 0.0402
# Epoch 8/40
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0352 - root_mean_squared_error: 0.0464 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0321 - val_root_mean_squared_error: 0.0448
# Epoch 9/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0364 - root_mean_squared_error: 0.0474 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0329 - val_root_mean_squared_error: 0.0446
# Epoch 10/40
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0342 - root_mean_squared_error: 0.0450 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0307 - val_root_mean_squared_error: 0.0422
# Epoch 11/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0372 - root_mean_squared_error: 0.0490 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0297 - val_root_mean_squared_error: 0.0399
# Epoch 12/40
# 24/24 [==============================] - 1s 34ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0341 - root_mean_squared_error: 0.0445 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0284 - val_root_mean_squared_error: 0.0388
# Epoch 13/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0328 - root_mean_squared_error: 0.0429 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0442
# Epoch 14/40
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0340 - root_mean_squared_error: 0.0441 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0428
# Epoch 15/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0320 - root_mean_squared_error: 0.0420 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0299 - val_root_mean_squared_error: 0.0389
# Epoch 16/40
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0329 - root_mean_squared_error: 0.0427 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0419
# Epoch 17/40
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0372 - root_mean_squared_error: 0.0477 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0273 - val_root_mean_squared_error: 0.0376
# Epoch 18/40
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0330 - root_mean_squared_error: 0.0432 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0458
# Epoch 19/40
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0320 - root_mean_squared_error: 0.0416 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0331 - val_root_mean_squared_error: 0.0422
# Epoch 20/40
# 24/24 [==============================] - 1s 37ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0318 - root_mean_squared_error: 0.0408 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0296 - val_root_mean_squared_error: 0.0384
# Epoch 21/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0297 - root_mean_squared_error: 0.0383 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0419
# Epoch 22/40
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0302 - root_mean_squared_error: 0.0392 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0325 - val_root_mean_squared_error: 0.0411
# Epoch 23/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0296 - root_mean_squared_error: 0.0386 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0285 - val_root_mean_squared_error: 0.0369
# Epoch 24/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0286 - root_mean_squared_error: 0.0374 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0306 - val_root_mean_squared_error: 0.0395
# Epoch 25/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0322 - root_mean_squared_error: 0.0421 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0309 - val_root_mean_squared_error: 0.0397
# Epoch 26/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0302 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0310 - val_root_mean_squared_error: 0.0417
# Epoch 27/40
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0296 - root_mean_squared_error: 0.0387 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0277 - val_root_mean_squared_error: 0.0362
# Epoch 28/40
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0304 - root_mean_squared_error: 0.0398 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0276 - val_root_mean_squared_error: 0.0358
# Epoch 29/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0284 - root_mean_squared_error: 0.0369 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0262 - val_root_mean_squared_error: 0.0356
# Epoch 30/40
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0291 - root_mean_squared_error: 0.0381 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0316 - val_root_mean_squared_error: 0.0391
# Epoch 31/40
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0296 - root_mean_squared_error: 0.0381 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0257 - val_root_mean_squared_error: 0.0344
# Epoch 32/40
# 24/24 [==============================] - 1s 38ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292 - root_mean_squared_error: 0.0386 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0322 - val_root_mean_squared_error: 0.0408
# Epoch 33/40
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0288 - root_mean_squared_error: 0.0379 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0275 - val_root_mean_squared_error: 0.0360
# Epoch 34/40
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0304 - root_mean_squared_error: 0.0392 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0280 - val_root_mean_squared_error: 0.0366
# Epoch 35/40
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0271 - root_mean_squared_error: 0.0352 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0269 - val_root_mean_squared_error: 0.0346
# Epoch 36/40
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0274 - root_mean_squared_error: 0.0354 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0282 - val_root_mean_squared_error: 0.0365
# Epoch 37/40
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0272 - root_mean_squared_error: 0.0358 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0260 - val_root_mean_squared_error: 0.0337
# Epoch 38/40
# 24/24 [==============================] - 1s 32ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0266 - root_mean_squared_error: 0.0352 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0301 - val_root_mean_squared_error: 0.0391
# Epoch 39/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0280 - root_mean_squared_error: 0.0364 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0256 - val_root_mean_squared_error: 0.0346
# Epoch 40/40
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0270 - root_mean_squared_error: 0.0349 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0289 - val_root_mean_squared_error: 0.0364

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(history.history['mse'], label='train MSE')
plt.plot(history.history['val_mse'], label='val MSE')
plt.xlabel("epoch")
plt.ylabel("MSE")
plt.legend()

# %%
plt.plot(history.history['mae'], label='train MAE')
plt.plot(history.history['val_mae'], label='val MAE')
plt.xlabel("epoch")
plt.ylabel("MAE")
plt.legend()

# %%
plt.plot(history.history['root_mean_squared_error'], label='train RMSE')
plt.plot(history.history['val_root_mean_squared_error'], label='val RMSE')
plt.xlabel("epoch")
plt.ylabel("RMSE")
plt.legend()

# %%
# After the model has been constructed, we'll summarise it
from tensorflow.keras.utils import plot_model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_14 (TimeDi  (None, 1, 98, 64)        256
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 1, 49, 64)        0
#  stributed)
#
#  time_distributed_16 (TimeDi  (None, 1, 47, 128)       24704
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 1, 23, 128)       0
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 1, 21, 64)        24640
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 1, 10, 64)        0
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 1, 640)           0
#  stributed)
#
#  gru_4 (GRU)                 (None, 1, 100)            222600
#
#  dropout_4 (Dropout)         (None, 1, 100)            0
#
#  gru_5 (GRU)                 (None, 100)               60600
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 332,901
# Trainable params: 332,901
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.evaluate(test_X, test_Y)
# Out:
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0289 - root_mean_squared_error: 0.0364
# [0.001326876925304532,
#  0.001326876925304532,
#  0.028936928138136864,
#  0.03642632067203522]

# %%
from sklearn.metrics import explained_variance_score, mean_poisson_deviance, mean_gamma_deviance
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % r2)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.878659
# R2 Score: 0.878442
# Max Error: 0.113456

# %%
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
plt.plot(test_label, color = 'red', label = 'Real Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 0s 7ms/step

# %% [markdown]
# # Testing

# %%
# First we need to save a model
model.save("modelCNNGRU.h5")

# %%
# Load model
new_model = tf.keras.models.load_model("./modelCNNGRU.h5")

# %%
new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_14 (TimeDi  (None, 1, 98, 64)        256
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 1, 49, 64)        0
#  stributed)
#
#  time_distributed_16 (TimeDi  (None, 1, 47, 128)       24704
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 1, 23, 128)       0
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 1, 21, 64)        24640
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 1, 10, 64)        0
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 1, 640)           0
#  stributed)
#
#  gru_4 (GRU)                 (None, 1, 100)            222600
#
#  dropout_4 (Dropout)         (None, 1, 100)            0
#
#  gru_5 (GRU)                 (None, 100)               60600
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 332,901
# Trainable params: 332,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# For data preprocessing and analysis part
# data2 = pd.read_excel('/content/drive/MyDrive/MachineLearning/ADRO.JK_dataprice.xlsx')
data2 = pd.read_excel('/content/drive/MyDrive/MachineLearning/BBCA_dataprice.xlsx')

data2.dropna(inplace=True)
data2.head()

data2.reset_index(drop=True, inplace=True)
data2.fillna(data.mean(), inplace=True)
data2.head()
df2 = data2.drop('Date', axis=1)
print(df2)

X = []
Y = []
window_size=100
for i in range(1 , len(df2) - window_size -1 , 1):
    # first = df2.iloc[i,4] # changed from iloc[i,4] to [i,2]
    first = df2.iloc[i,2]
    temp = []
    temp2 = []
    for j in range(window_size):
        # temp.append((df2.iloc[i + j, 4] - first) / first) #changed 4 to 2
        temp.append((df2.iloc[i + j, 2] - first) / first)
    # for j in range(week):
    # temp2.append((df2.iloc[i + window_size, 4] - first) / first) #changed 4 to 2
    temp2.append((df2.iloc[i + window_size, 2] - first) / first)
    # X.append(np.array(stock.iloc[i:i+window_size,4]).reshape(50,1))
    # Y.append(np.array(stock.iloc[i+window_size,4]).reshape(1,1))
    # print(stock2.iloc[i:i+window_size,4])
    X.append(np.array(temp).reshape(100, 1))
    Y.append(np.array(temp2).reshape(1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

train_X = np.array(x_train)
test_X = np.array(x_test)
train_Y = np.array(y_train)
test_Y = np.array(y_test)

train_X = train_X.reshape(train_X.shape[0],1,100,1)
test_X = test_X.reshape(test_X.shape[0],1,100,1)

print(len(train_X))
print(len(test_X))
# Out:
# <ipython-input-98-cb91387b680e>:9: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data2.fillna(data.mean(), inplace=True)
#              Open         High          Low        Close      Volume  \
# 0     3435.631645  3477.191706  3431.013861  3454.102783  65311000.0
# 1     3486.427273  3504.898411  3458.720566  3495.662842  88810000.0
# 2     3495.662842  3504.898411  3477.191704  3495.662842  62681500.0
# 3     3518.751793  3518.751793  3426.396103  3463.338379  43917500.0
# 4     3463.338654  3463.338654  3426.396375  3431.014160  70007000.0
# ...           ...          ...          ...          ...         ...
# 1250  7350.000000  7375.000000  7300.000000  7300.000000  31247600.0
# 1251  7250.000000  7375.000000  7250.000000  7300.000000  44379900.0
# 1252  7325.000000  7350.000000  7275.000000  7325.000000  58465500.0
# 1253  7375.000000  7450.000000  7325.000000  7350.000000  86909700.0
# 1254  7400.000000  7475.000000  7375.000000  7425.000000  60044300.0
#
#       Dividends  Stock Splits
# 0           0.0             0
# 1           0.0             0
# 2           0.0             0
# 3           0.0             0
# 4           0.0             0
# ...         ...           ...
# 1250        0.0             0
# 1251        0.0             0
# 1252        0.0             0
# 1253        0.0             0
# 1254        0.0             0
#
# [1255 rows x 7 columns]
# 922
# 231

# %%
model.evaluate(test_X, test_Y)
# Out:
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0277 - root_mean_squared_error: 0.0333
# [0.001108907163143158,
#  0.001108907163143158,
#  0.02767411805689335,
#  0.033300258219242096]

# %%
predicted  = model.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(train_X)
for j in range(len_t , len_t + len(test_X)):
    temp = data2.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
plt.plot(test_label, color = 'red', label = 'Real Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 0s 12ms/step

# %%
# Converting model from HDF5 format to TFJS format...
# !pip install tensorflowjs[wizard]
# Need to be done on a CLI and not in notebook
# !tensorflowjs_converter --input_format=keras /kaggle/working/model.h5 /kaggle/working/model-tjs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflowjs[wizard] in /usr/local/lib/python3.10/dist-packages (4.6.0)
# Requirement already satisfied: flax<0.6.3,>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (0.6.2)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (5.12.0)
# Requirement already satisfied: jax>=0.3.16 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (0.4.10)
# Requirement already satisfied: tensorflow<3,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (2.12.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (1.3.0)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (1.16.0)
# Requirement already satisfied: tensorflow-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (0.13.0)
# Requirement already satisfied: packaging~=20.9 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (20.9)
# Requirement already satisfied: PyInquirer==1.0.3 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs[wizard]) (1.0.3)
# Requirement already satisfied: prompt-toolkit==1.0.14 in /usr/local/lib/python3.10/dist-packages (from PyInquirer==1.0.3->tensorflowjs[wizard]) (1.0.14)
# Requirement already satisfied: Pygments>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from PyInquirer==1.0.3->tensorflowjs[wizard]) (2.14.0)
# Requirement already satisfied: regex>=2016.11.21 in /usr/local/lib/python3.10/dist-packages (from PyInquirer==1.0.3->tensorflowjs[wizard]) (2022.10.31)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit==1.0.14->PyInquirer==1.0.3->tensorflowjs[wizard]) (0.2.6)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (3.7.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (1.0.5)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (0.1.5)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (0.1.36)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (13.3.4)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (4.5.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (6.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.16->tensorflowjs[wizard]) (0.1.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.16->tensorflowjs[wizard]) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.16->tensorflowjs[wizard]) (1.10.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from packaging~=20.9->tensorflowjs[wizard]) (3.0.9)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (3.8.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (16.0.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (67.7.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (0.32.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.3.0->tensorflowjs[wizard]) (1.5.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.3.0->tensorflowjs[wizard]) (0.40.0)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.3.0->tensorflowjs[wizard]) (3.0.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (2.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (2.8.2)
# Requirement already satisfied: chex>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from optax->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (0.1.7)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.10/dist-packages (from optax->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (0.4.10+cuda11.cudnn86)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests>=1.3.0->tensorflowjs[wizard]) (2022.7.1)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (0.12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.1->flax<0.6.3,>=0.6.2->tensorflowjs[wizard]) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<3,>=2.12.0->tensorflowjs[wizard]) (3.2.2)
# 2023-05-29 18:47:01.945639: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorflowjs_converter", line 8, in <module>
#     sys.exit(pip_main())
#   File "/usr/local/lib/python3.10/dist-packages/tensorflowjs/converters/converter.py", line 827, in pip_main
#     main([' '.join(sys.argv[1:])])
#   File "/usr/local/lib/python3.10/dist-packages/tensorflowjs/converters/converter.py", line 831, in main
#     convert(argv[0].split(' '))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflowjs/converters/converter.py", line 817, in convert
#     _dispatch_converter(input_format, output_format, args, quantization_dtype_map,
#   File "/usr/local/lib/python3.10/dist-packages/tensorflowjs/converters/converter.py", line 500, in _dispatch_converter
#     dispatch_keras_h5_to_tfjs_layers_model_conversion(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflowjs/converters/converter.py", line 76, in dispatch_keras_h5_to_tfjs_layers_model_conversion
#     raise ValueError('Nonexistent path to HDF5 file: %s' % h5_path)
# ValueError: Nonexistent path to HDF5 file: /kaggle/working/model.h5

# %% [markdown]
# # EDA

# %%
dataX = pd.read_excel('/content/drive/MyDrive/MachineLearning/BBCA_dataprice.xlsx')
dataX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1256 entries, 0 to 1255
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1256 non-null   datetime64[ns]
#  1   Open          1255 non-null   float64
#  2   High          1255 non-null   float64
#  3   Low           1255 non-null   float64
#  4   Close         1255 non-null   float64
#  5   Volume        1255 non-null   float64
#  6   Dividends     1256 non-null   float64
#  7   Stock Splits  1256 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 78.6 KB

# %%
dataX.head()
# Out:
#         Date         Open         High          Low        Close      Volume  \
# 0 2017-07-31  3435.631645  3477.191706  3431.013861  3454.102783  65311000.0
# 1 2017-08-01  3486.427273  3504.898411  3458.720566  3495.662842  88810000.0
# 2 2017-08-02  3495.662842  3504.898411  3477.191704  3495.662842  62681500.0
# 3 2017-08-03  3518.751793  3518.751793  3426.396103  3463.338379  43917500.0
# 4 2017-08-04  3463.338654  3463.338654  3426.396375  3431.014160  70007000.0
#
#    Dividends  Stock Splits
# 0        0.0             0
# 1        0.0             0
# 2        0.0             0
# 3        0.0             0
# 4        0.0             0

# %%
start_date = '2017-07-31'
end_date = '2022-07-29'

fill = (dataX['Date']>=start_date) & (dataX['Date']<=end_date)
dataX = dataX.loc[fill]
dataX
# Out:
#            Date         Open         High          Low        Close  \
# 0    2017-07-31  3435.631645  3477.191706  3431.013861  3454.102783
# 1    2017-08-01  3486.427273  3504.898411  3458.720566  3495.662842
# 2    2017-08-02  3495.662842  3504.898411  3477.191704  3495.662842
# 3    2017-08-03  3518.751793  3518.751793  3426.396103  3463.338379
# 4    2017-08-04  3463.338654  3463.338654  3426.396375  3431.014160
# ...         ...          ...          ...          ...          ...
# 1251 2022-07-25  7350.000000  7375.000000  7300.000000  7300.000000
# 1252 2022-07-26  7250.000000  7375.000000  7250.000000  7300.000000
# 1253 2022-07-27  7325.000000  7350.000000  7275.000000  7325.000000
# 1254 2022-07-28  7375.000000  7450.000000  7325.000000  7350.000000
# 1255 2022-07-29  7400.000000  7475.000000  7375.000000  7425.000000
#
#           Volume  Dividends  Stock Splits
# 0     65311000.0        0.0             0
# 1     88810000.0        0.0             0
# 2     62681500.0        0.0             0
# 3     43917500.0        0.0             0
# 4     70007000.0        0.0             0
# ...          ...        ...           ...
# 1251  31247600.0        0.0             0
# 1252  44379900.0        0.0             0
# 1253  58465500.0        0.0             0
# 1254  86909700.0        0.0             0
# 1255  60044300.0        0.0             0
#
# [1256 rows x 8 columns]

# %%
dataX.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1255.000000  1255.000000  1255.000000  1255.000000  1.255000e+03
# mean   5615.642379  5666.128212  5558.915038  5612.780879  7.983317e+07
# std    1186.870797  1196.635812  1174.073975  1184.910905  4.870713e+07
# min    3435.631645  3463.338435  3417.160615  3431.014160  0.000000e+00
# 25%    4483.680176  4530.385016  4446.316309  4483.680176  5.269025e+07
# 50%    5674.348905  5712.178006  5636.520720  5674.349609  7.020700e+07
# 75%    6404.430224  6451.279984  6363.451912  6400.107910  9.668335e+07
# max    8250.000000  8250.000000  8075.000000  8200.000000  5.379715e+08
#
#          Dividends  Stock Splits
# count  1256.000000   1256.000000
# mean      0.382962      0.003981
# std       5.336629      0.141083
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max     120.000000      5.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import r2_score,mean_squared_error

sns_plot = sns.distplot(dataX['Close'])
# Out:
# <ipython-input-106-8b85444e1395>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns_plot = sns.distplot(dataX['Close'])

# %%
fig, ax = plt.subplots(4, 2, figsize = (15, 13))
sns.boxplot(x= dataX["Close"], ax = ax[0,0])
sns.distplot(dataX['Close'], ax = ax[0,1])
sns.boxplot(x= dataX["Open"], ax = ax[1,0])
sns.distplot(dataX['Open'], ax = ax[1,1])
sns.boxplot(x= dataX["High"], ax = ax[2,0])
sns.distplot(dataX['High'], ax = ax[2,1])
sns.boxplot(x= dataX["Low"], ax = ax[3,0])
sns.distplot(dataX['Low'], ax = ax[3,1])
plt.tight_layout()
# Out:
# <ipython-input-107-5df29a997472>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataX['Close'], ax = ax[0,1])
# <ipython-input-107-5df29a997472>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataX['Open'], ax = ax[1,1])
# <ipython-input-107-5df29a997472>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataX['High'], ax = ax[2,1])
# <ipython-input-107-5df29a997472>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataX['Low'], ax = ax[3,1])

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dataX.corr(),cmap=plt.cm.Reds,annot=True)
plt.title('Heatmap',
         fontsize=13)
plt.show()
# Out:
# <ipython-input-108-f5ccb507b81d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dataX.corr(),cmap=plt.cm.Reds,annot=True)

# %% [markdown]
# References: [Stock Market prediction using CNN-LSTM](https://www.kaggle.com/code/aadhityaa/stock-market-prediction-using-cnn-lstm#Training-part)
